# %% [markdown]
# # Introdução ao Scikit-learn com o dataset Heart Disease
#
# [Dataset URL](https://archive.ics.uci.edu/ml/datasets/Heart+Disease)

# %%
import numpy as np
import pandas as pd

# %%
#import the Cleveland heart patient data file using pandas, creating a header row
#since file doesn't have column names

hd_dir = "~/Dropbox/Machine Learning - AE/Projetos/Heart Disease Diagnosis/"

header_row = ['age','sex','pain','BP','chol','fbs','ecg','maxhr','eiang','eist','slope','vessels','thal','diagnosis']
heart = pd.read_csv(hd_dir + 'processed.cleveland.data', names=header_row)

# %%
heart
# Out:
#      age  sex  pain   BP  chol  fbs  ecg  maxhr  eiang  eist  slope vessels  \
# 0     63    1     1  145   233    1    2    150      0   2.3      3     0.0
# 1     67    1     4  160   286    0    2    108      1   1.5      2     3.0
# 2     67    1     4  120   229    0    2    129      1   2.6      2     2.0
# 3     37    1     3  130   250    0    0    187      0   3.5      3     0.0
# 4     41    0     2  130   204    0    2    172      0   1.4      1     0.0
# 5     56    1     2  120   236    0    0    178      0   0.8      1     0.0
# 6     62    0     4  140   268    0    2    160      0   3.6      3     2.0
# 7     57    0     4  120   354    0    0    163      1   0.6      1     0.0
# 8     63    1     4  130   254    0    2    147      0   1.4      2     1.0
# 9     53    1     4  140   203    1    2    155      1   3.1      3     0.0
# 10    57    1     4  140   192    0    0    148      0   0.4      2     0.0
# ...
